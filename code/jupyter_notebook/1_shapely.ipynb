# %%
# dev mode
import sys

# add path
sys.path.insert(0, "../../code/src/")

# interactively load the module
# %load_ext autoreload
# %autoreload 2

# %%
from hierarchical_grouping.file_reader import BinaryPolygonFileReader, test_load_module
from hierarchical_grouping.utils import plot_two_polys
import shapely.plotting

# %%
test_load_module()
# Out:
# NEWww

# %% [markdown]
# # 1. Import data

# %%
'''
    Name,            number of sets
    data_auerberg,              796
    data_dottendorf,            871
    data_duisdorf,             2127
    data_endenich,             1060
    data_zentrum,               160
'''
file_path = "../data/data_auerberg"
reader = BinaryPolygonFileReader(file_path)

# %% [markdown]
# # 2. Learn what's inside the Polygon

# %%
set_id, polys1, polys2 = reader.read_next_set()

# %% [markdown]
# ## 2.1 Type
# polys1 and polys2 both are sets of polygon in which contain [Polygon](https://shapely.readthedocs.io/en/stable/reference/shapely.Polygon.html).

# %%
print("First Set of Polygons:")
for poly in polys1:
    print(poly)
# Out:
# First Set of Polygons:
# POLYGON ((363900.78247214016 5623756.2700769445, 363887.6120797179 5623747.111862066, 363910.53719354235 5623712.957195817, 363915.2281592062 5623704.178651792, 363913.5873901872 5623703.787524667, 363918.4430175845 5623694.014456876, 363920.2588836743 5623694.623543088, 363924.4792856059 5623684.310738932, 363940.26425267576 5623691.409277115, 363924.02175320336 5623720.627490429, 363925.73557056196 5623721.383880353, 363902.5253674127 5623757.05907907, 363900.78247214016 5623756.2700769445))
# POLYGON ((363377.59209196945 5623931.196856269, 363338.06386681716 5623827.422705264, 363263.6127618407 5623856.365729567, 363257.0348930448 5623844.544005728, 363254.1555136725 5623831.368081916, 363359.7334451019 5623790.483388624, 363348.59914030053 5623761.001119573, 363722.47128695576 5623614.848203069, 363723.73249023757 5623618.5425482225, 363818.4752820452 5623582.523362003, 363967.86532917805 5623647.330773051, 363965.7096022248 5623651.826332051, 363979.89479791257 5623658.210119244, 363941.0696321456 5623742.324052536, 363925.03010639694 5623735.743962641, 363921.97334237467 5623734.37727836, 363940.26425267576 5623691.409277115, 363924.4792856059 5623684.310738932, 363920.2588836743 5623694.623543088, 363918.4430175845 5623694.014456876, 363897.14642796083 5623683.98891984, 363898.2609949362 5623679.631750031, 363836.74409480765 5623652.864942808, 363835.6253989885 5623656.521283655, 363777.0812318963 5623630.3562757345, 363751.063602787 5623640.136859827, 363753.4298858332 5623644.792588099, 363634.5041820821 5623691.035823346, 363635.7175091377 5623694.787032122, 363593.6006934203 5623711.097520882, 363595.3200880566 5623716.115008464, 363576.70997610025 5623724.089536366, 363572.9784368096 5623715.007957736, 363558.4425566761 5623720.873297298, 363561.52668821975 5623729.760397711, 363498.5619906612 5623754.2828811435, 363494.9645011027 5623745.743031932, 363467.7359744805 5623756.146449064, 363470.1254691115 5623763.838918014, 363437.1216834682 5623776.885912775, 363439.45026818657 5623783.867883485, 363481.7701405783 5623890.273350725, 363377.59209196945 5623931.196856269))

# %% [markdown]
# [Polygon](https://shapely.readthedocs.io/en/stable/reference/shapely.Polygon.html) is of type shapely.Polygon which contains properties such as
#     - area
#     - boundary, for example.

# %%
print("The unit of type Polygon is no unit")
print("but our data, they are in UTM coordinate system. So, the unit meter square")
print("Area of the pythons inside the set:")
for poly in polys1:
    print(poly.area)
# Out:
# The unit of type Polygon is no unit
# but our data, they are in UTM coordinate system. So, the unit meter square
# Area of the pythons inside the set:
# 1281.1760604577128
# 47794.24519869465

# %%
shapely.plotting.plot_polygon(polys1[0])
# Out:
# (<matplotlib.patches.PathPatch at 0x7f8e88d23be0>,
#  <matplotlib.lines.Line2D at 0x7f8e88d23fa0>)

# %%
shapely.plotting.plot_polygon(polys1[1])
# Out:
# (<matplotlib.patches.PathPatch at 0x7f8eb8d87430>,
#  <matplotlib.lines.Line2D at 0x7f8eb8d877c0>)

# %%
# shapely.plotting.plot_polygon(polys1[2])

# %%
# shapely.plotting.plot_polygon(polys1[3])

# %%
for poly in polys1:
    shapely.plotting.plot_polygon(poly)

# %%
for poly in polys2:
    shapely.plotting.plot_polygon(poly)

# %% [markdown]
# # 3. Next sets

# %%
set_id, polys1, polys2 = reader.read_next_set()

# %%
print("set_id: ", set_id)
print("Length polys1: ", len(polys1))
print("Length polys2: ", len(polys2))
# Out:
# set_id:  1
# Length polys1:  1
# Length polys2:  1

# %%
for poly in polys1:
    shapely.plotting.plot_polygon(poly)

# %%
for poly in polys2:
    shapely.plotting.plot_polygon(poly)

# %% [markdown]
# # [Plotting](https://shapely.readthedocs.io/en/latest/plotting.html)

# %% [markdown]
# # 3. Interesing polyss.
# ## 3.1 data_auerberg, set_id: 31
# length of polygon1 is 2.
# length of polygon2 is 4.

# %% [markdown]
# <img src="img/1_shapely/data_auerberg/31.png" width="400" height="300" alt="Image description">

# %% [markdown]
# ## 3.2 data_auerberg, set_id: 37
# length of polygon1 is 2.
# length of polygon2 is 8.

# %% [markdown]
# <img src="img/1_shapely/data_auerberg/37.png" width="400" height="300" alt="Image description">

# %% [markdown]
# ## 4. Ideas.
# 4.1 the highest of sharing boundary.

# %% [markdown]
# # 99. TODO
# ## 99.1 Build the array index of the class. eg reader[31] = should returns the 31st set_id's data.
